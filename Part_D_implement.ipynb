# %%
import numpy as np
from scipy import stats

# Given data
mu = 50        # population mean
x_bar = 47     # sample mean
sigma = 5      # population std
n = 30         # sample size

# Step 1: Compute Z-score
z = (x_bar - mu) / (sigma / np.sqrt(n))

# Step 2: Compute p-value (left-tailed test)
p_value = stats.norm.cdf(z)

print("Z-score:", z)
print("p-value:", p_value)

# Step 3: Decision
alpha = 0.05
if p_value < alpha:
    print("Reject H0: Battery life is significantly lower.")
else:
    print("Fail to reject H0.")
# Out:
# Z-score: -3.2863353450309964
# p-value: 0.0005075004735565336
# Reject H0: Battery life is significantly lower.
